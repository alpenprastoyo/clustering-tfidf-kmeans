# %%
import pandas as pd 
import numpy as np

abstrack = pd.read_csv("data_abstrak.csv")

abstrack['abstrack'] = abstrack['abstrack'].str.lower()
print(abstrack)
# Out:
#                                              abstrack
# 0   bagus prasetyo hutomo, 2016. pembuatan sistem ...
# 1   today customers can easily submit their review...
# 2   the purpose of this research is to present sym...
# 3   5\tabstrak\r\n\r\nsetiap tahunnya smpit nur hi...
# 4   berbagai pendidikan melalui pembelajaran yang ...
# ..                                                ...
# 78  novita rahmawati. evaluasi penerapan technolog...
# 79  abstrak\r\nrezza fariszal hisyam chaizara. k35...
# 80  this study aims to improve the activeness and ...
# 81  perkembangan era digitalisasi yang sangat pesa...
# 82  perkembangan era digitalisasi yang sangat pesa...
#
# [83 rows x 1 columns]

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
nltk.download('punkt')


# ------ Tokenizing ---------

def remove_abstrack_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
abstrack['abstrack'] = abstrack['abstrack'].apply(remove_abstrack_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

abstrack['abstrack'] = abstrack['abstrack'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

abstrack['abstrack'] = abstrack['abstrack'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

abstrack['abstrack'] = abstrack['abstrack'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

abstrack['abstrack'] = abstrack['abstrack'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

abstrack['abstrack'] = abstrack['abstrack'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

abstrack['abstrack_tokens'] = abstrack['abstrack'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(abstrack['abstrack_tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [bagus, prasetyo, hutomo, pembuatan, sistem, a...
# 1    [today, customers, can, easily, submit, their,...
# 2    [the, purpose, of, this, research, is, to, pre...
# 3    [abstrak, setiap, tahunnya, smpit, nur, hidaya...
# 4    [berbagai, pendidikan, melalui, pembelajaran, ...
# Name: abstrack_tokens, dtype: object
# [nltk_data] Downloading package punkt to C:\Users\Alpen
# [nltk_data]     Prastoyo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

abstrack['abstrack_tokens_fdist'] = abstrack['abstrack_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(abstrack['abstrack_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(yang, 17), (sistem, 14), (data, 9), (pasien,...
# 1    [(the, 26), (is, 12), (of, 9), (class, 9), (an...
# 2    [(the, 9), (face, 7), (to, 6), (of, 5), (ssvdr...
# 3    [(yang, 12), (dengan, 11), (dan, 10), (data, 9...
# 4    [(pembelajaran, 7), (yang, 5), (sistem, 5), (p...
# Name: abstrack_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

abstrack['abstrack_tokens_WSW'] = abstrack['abstrack_tokens'].apply(stopwords_removal) 


print(abstrack['abstrack_tokens_WSW'].head())
# Out:
# 0    [bagus, prasetyo, hutomo, pembuatan, sistem, a...
# 1    [today, customers, can, easily, submit, their,...
# 2    [the, purpose, of, this, research, is, to, pre...
# 3    [abstrak, tahunnya, smpit, nur, hidayah, mener...
# 4    [pendidikan, pembelajaran, berbasiskan, teknol...
# Name: abstrack_tokens_WSW, dtype: object
# [nltk_data] Downloading package stopwords to C:\Users\Alpen
# [nltk_data]     Prastoyo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in abstrack['abstrack_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

abstrack['abstrack_tokens_stemmed'] = abstrack['abstrack_tokens_WSW'].swifter.apply(get_stemmed_term)
print(abstrack['abstrack_tokens_stemmed'])
# Out:
# 2471
# ------------------------
# bagus : bagus
# prasetyo : prasetyo
# hutomo : hutomo
# pembuatan : buat
# sistem : sistem
# administrasi : administrasi
# rawat : rawat
# jalan : jalan
# berbasis : bas
# php : php
# rumah : rumah
# sakit : sakit
# kepentingan : penting
# pengolahan : olah
# data : data
# pendaftaran : daftar
# pasien : pasien
# tindakan : tindak
# pembayaran : bayar
# menangani : tangan
# berjalan : jalan
# cepat : cepat
# kelola : kelola
# valid : valid
# pku : pku
# muhammadiyah : muhammadiyah
# surakarta : surakarta
# memiliki : milik
# kompleks : kompleks
# pengelolaan : kelola
# efektif : efektif
# fungsi : fungsi
# kartu : kartu
# berguna : guna
# pengenal : kenal
# observasi : observasi
# memperoleh : oleh
# proses : proses
# nyata : nyata
# membentuk : bentuk
# informasi : informasi
# atribut : atribut
# penyimpanan : simpan
# database : database
# dikumpulkan : kumpul
# olah : olah
# komponen : komponen
# perancangan : ancang
# dimana : mana
# erd : erd
# usecase : usecase
# class : class
# diagram : diagram
# sequence : sequence
# tampilan : tampil
# hasil : hasil
# diperoleh : oleh
# penelitian : teliti
# diolah : olah
# ditangani : tangan
# pengujian : uji
# memeriksa : periksa
# program : program
# lancar : lancar
# percetakan : cetak
# anggota : anggota
# admin : admin
# penambahan : tambah
# poliklinik : poliklinik
# diagnosis : diagnosis
# cetak : cetak
# nota : nota
# kunci : kunci
# web : web
# today : today
# customers : customers
# can : can
# easily : easily
# submit : submit
# their : their
# review : review
# or : or
# opinion : opinion
# of : of
# product : product
# service : service
# from : from
# natasha : natasha
# skin : skin
# care : care
# through : through
# mentions : mentions
# tweet : tweet
# be : be
# identified : identified
# emotions : emotions
# costumers : costumers
# after : after
# using : using
# products : products
# services : services
# this : this
# research : research
# proposes : proposes
# to : to
# classify : classify
# according : according
# ekman : ekman
# that : that
# is : is
# joy : joy
# surprise : surprise
# anger : anger
# fear : fear
# sad : sad
# and : and
# disgust : disgust
# by : by
# nave : nave
# bayes : bayes
# classifier : classifier
# chosen : chosen
# because : because
# its : its
# advantages : advantages
# simple : simple
# fast : fast
# high : high
# accuracy : accuracy
# the : the
# dataset : dataset
# in : in
# study : study
# amounted : amounted
# with : with
# division : division
# for : for
# each : each
# noemotions : noemotions
# results : results
# show : show
# method : method
# has : has
# good : good
# performance : performance
# twitter : twitter
# average : average
# rate : rate
# on : on
# emotional : emotional
# classification : classification
# without : without
# involving : involving
# shows : shows
# highest : highest
# recall : recall
# value : value
# precision : precision
# was : was
# fmeasure : fmeasure
# mean : mean
# although : although
# higher : higher
# very : very
# low : low
# which : which
# ros : ros
# resampling : resampling
# algorithm : algorithm
# values : values
# are : are
# keyword : keyword
# purpose : purpose
# present : present
# symmetrical : symmetrical
# singular : singular
# decomposition : decomposition
# representation : representation
# ssvdr : ssvdr
# gabor : gabor
# filter : filter
# under : under
# illumination : illumination
# effect : effect
# face : face
# recognition : recognition
# proposed : proposed
# normalize : normalize
# illuminated : illuminated
# images : images
# caused : caused
# difference : difference
# light : light
# represented : represented
# characteristics : characteristics
# lowintensity : lowintensity
# combined : combined
# reversed : reversed
# part : part
# based : based
# svd : svd
# used : used
# extract : extract
# were : were
# already : already
# processed : processed
# order : order
# do : do
# pca : pca
# lda : lda
# methods : methods
# nearest : nearest
# neighbor : neighbor
# as : as
# techniques : techniques
# represent : represent
# highdimensional : highdimensional
# into : into
# lower : lower
# dimensions : dimensions
# whereas : whereas
# identify : identify
# closest : closest
# distance : distance
# result : result
# showed : showed
# obtained : obtained
# abstrak : abstrak
# tahunnya : tahun
# smpit : smpit
# nur : nur
# hidayah : hidayah
# menerima : terima
# meluluskan : lulus
# siswa : siswa
# bertambah : tambah
# nilai : nilai
# strategis : strategis
# dianalisa : dianalisa
# maksimal : maksimal
# mencari : cari
# polapola : polapola
# menarik : tarik
# meningkatkan : tingkat
# kualitas : kualitas
# pendidikan : didik
# mining : mining
# metode : metode
# association : association
# rule : rule
# algoritma : algoritma
# apriori : apriori
# pola : pola
# hubungan : hubung
# orang : orang
# tua : tua
# anak : anak
# angkatan : angkat
# masuk : masuk
# lulus : lulus
# sekolah : sekolah
# terbentuk : bentuk
# confidencenya : confidencenya
# diatas : atas
# consequent : consequent
# pai : pai
# uan : uan
# eliminasi : eliminasi
# consequentnya : consequentnya
# terkait : kait
# terkalit : terkalit
# network : network
# analysis : analysis
# nodenya : nodenya
# kemunculannya : muncul
# dominan : dominan
# muncul : muncul
# kuat : kuat
# edgenya : edgenya
# paib : paib
# lakilaki : lakilaki
# uana : uana
# baca : baca
# quran : quran
# ayah : ayah
# perempuan : perempuan
# sd : sd
# jarak : jarak
# gaji : gaji
# pembelajaran : ajar
# berbasiskan : basis
# teknologi : teknologi
# diterapkan : terap
# elektronik : elektronik
# elearning : elearning
# kekurangan : kurang
# pembelajarannya : ajar
# memperhatikan : perhati
# keragaman : ragam
# kemampuan : mampu
# penggunanya : guna
# individual : individual
# intelligent : intelligent
# tutoring : tutoring
# system : system
# salah : salah
# solusi : solusi
# mendukung : dukung
# bertujuan : tuju
# membangun : bangun
# aplikasi : aplikasi
# pemodelan : model
# ontologi : ontologi
# casebased : casebased
# reasoning : reasoning
# cbr : cbr
# java : java
# programming : programming
# menyediakan : sedia
# bimbingan : bimbing
# belajar : ajar
# pengguna : guna
# menyesuaikan : sesuai
# berperan : peran
# pemetaan : meta
# bahan : bahan
# membantu : bantu
# adaptif : adaptif
# userfriendly : userfriendly
# berdasarkan : dasar
# evaluasi : evaluasi
# usability : usability
# diterima : terima
# mencapai : capai
# angka : angka
# skala : skala
# diagnosa : diagnosa
# acute : acute
# myeloid : myeloid
# leukemia : leukemia
# aml : aml
# memanfaatkan : manfaat
# citra : citra
# preprocessing : preprocessing
# segmentasi : segmentasi
# ekstraksi : ekstraksi
# ciri : ciri
# memisahkan : pisah
# objek : objek
# backgroundnya : backgroundnya
# contoh : contoh
# static : static
# thresholding : thresholding
# multi : multi
# otsu : otsu
# membandingkan : banding
# meliputi : liput
# median : median
# filtering : filtering
# konversi : konversi
# warna : warna
# ycbcr : ycbcr
# operasi : operasi
# morfologi : morfologi
# identifikasi : identifikasi
# uji : uji
# diameter : diameter
# wbc : wbc
# rasio : rasio
# nukleus : nukleus
# putaran : putar
# menghasilkan : hasil
# akurasi : akurasi
# akurasinya : akurasi
# klasifikasi : klasifikasi
# dibandingkan : banding
# abstract : abstract
# process : process
# diagnosing : diagnosing
# done : done
# utilizing : utilizing
# image : image
# processing : processing
# consisting : consisting
# segmentation : segmentation
# feature : feature
# extraction : extraction
# separate : separate
# objects : objects
# background : background
# one : one
# example : example
# threshholding : threshholding
# aims : aims
# compare : compare
# between : between
# initial : initial
# color : color
# space : space
# morphological : morphological
# operation : operation
# identificating : identificating
# cell : cell
# uses : uses
# test : test
# form : form
# ratio : ratio
# roundness : roundness
# it : it
# shown : shown
# give : give
# better : better
# an : an
# only : only
# keywords : keywords
# keterlambatan : lambat
# aircraft : aircraft
# sequencing : sequencing
# problem : problem
# pengaruh : pengaruh
# dunia : dunia
# penerbangan : terbang
# dimodelkan : model
# penjadwalan : jadwal
# mesin : mesin
# paralel : paralel
# landasan : landas
# pesawat : pesawat
# pekerjaan : kerja
# tipe : tipe
# penalty : penalty
# fuel : fuel
# burn : burn
# ready : ready
# time : time
# deadline : deadline
# taxi : taxi
# runway : runway
# occupancy : occupancy
# pengurutan : urut
# tergantung : gantung
# separation : separation
# menghindari : hindar
# tabrakan : tabrak
# menugaskan : tugas
# mengurutkan : urut
# menentukan : tentu
# kedatangan : datang
# keberangkatan : berangkat
# terpilih : pilih
# memperkecil : kecil
# total : total
# delay : delay
# cost : cost
# tujuan : tuju
# menjadwalkan : jadwal
# sedekat : dekat
# target : target
# timenya : timenya
# greedy : greedy
# earliest : earliest
# fisrt : fisrt
# priority : priority
# index : index
# bersamaan : sama
# dihasilkan : hasil
# kinerjanya : kerja
# dievaluasi : evaluasi
# eksekusi : eksekusi
# air : air
# traffic : traffic
# contoller : contoller
# algorithms : algorithms
# kebutuhan : butuh
# pokok : pokok
# komoditas : komoditas
# memegang : pegang
# peranan : peran
# aspek : aspek
# ekonomi : ekonomi
# sosial : sosial
# politik : politik
# negara : negara
# indonesia : indonesia
# berpengaruh : pengaruh
# hajat : hajat
# hidup : hidup
# pemenuhan : penuh
# faktor : faktor
# pendukung : dukung
# kesejahteraan : sejahtera
# masyarakat : masyarakat
# permasalahan : masalah
# klasik : klasik
# rangka : rangka
# fluktuasi : fluktuasi
# harga : harga
# kenaikan : naik
# pemicu : picu
# utama : utama
# inflasi : inflasi
# mengatasi : atas
# upaya : upaya
# pemerintah : perintah
# kebijakan : bijak
# stabilisasi : stabilisasi
# petani : tani
# produsen : produsen
# menguntungkan : untung
# konsumen : konsumen
# membeli : beli
# terjangkau : jangkau
# mengakomodasi : akomodasi
# langkah : langkah
# peramalan : amal
# memprediksi : prediksi
# prediksi : prediksi
# nasional : nasional
# fuzzy : fuzzy
# series : series
# pendekatan : dekat
# song : song
# chissom : chissom
# markov : markov
# chain : chain
# periode : periode
# mingguan : minggu
# dibagi : bagi
# tahap : tahap
# training : training
# testing : testing
# mape : mape
# kelayakan : layak
# kesimpulan : simpul
# interval : interval
# implementasi : implementasi
# learning : learning
# management : management
# lms : lms
# mengalami : alami
# kegagalan : gagal
# disebabkan : sebab
# pemilihan : pilih
# platform : platform
# pemangku : mang
# perangkat : perangkat
# lunak : lunak
# permasalahannya : masalah
# parameter : parameter
# sesuai : sesuai
# mendorong : dorong
# memilih : pilih
# pemilihannya : pilih
# menerapkan : terap
# saw : saw
# topsis : topsis
# criteria : criteria
# decision : decision
# making : making
# mcdm : mcdm
# diharapkan : harap
# keputusan : putus
# konsisten : konsisten
# perbandingan : banding
# analisis : analisis
# korelasi : korelasi
# top : top
# open : open
# source : source
# atutor : atutor
# chamilo : chamilo
# dokeos : dokeos
# efront : efront
# formalms : formalms
# ilias : ilias
# moodle : moodle
# opigno : opigno
# dipilih : pilih
# delapan : delapan
# isoiec : isoiec
# mengumpulkan : kumpul
# kode : kode
# sumber : sumber
# diukur : ukur
# kualitasnya : kualitas
# phpmetrics : phpmetrics
# tools : tools
# perubahan : ubah
# bobot : bobot
# kriteria : kriteria
# dianalisis : analis
# pearson : pearson
# spearman : spearman
# menduduki : duduk
# peringkat : peringkat
# koefisien : koefisien
# menujukkan : menujukkan
# erat : erat
# setara : tara
# seni : seni
# rupa : rupa
# interpretasi : interpretasi
# tanggapan : tanggap
# pengalaman : alam
# manusia : manusia
# bentuk : bentuk
# visual : visual
# rabaan : raba
# penilain : penilain
# karya : karya
# kritik : kritik
# dewasa : dewasa
# mengemukakan : muka
# penilaian : nilai
# mempertimbangkan : timbang
# dikemukakan : muka
# text : text
# satunya : satu
# kelebihan : lebih
# sederhana : sederhana
# selection : selection
# documentfrequency : documentfrequency
# pembobotan : bobot
# term : term
# frequency : frequency
# document : document
# tfidf : tfidf
# diklasifikasikan : klasifikasi
# kategori : kategori
# positif : positif
# negatif : negatif
# tertinggi : tinggi
# presisi : presisi
# pembangkitan : bangkit
# rating : rating
# implisit : implisit
# sentiment : sentiment
# kalangan : kalang
# split : split
# delivery : delivery
# vehicle : vehicle
# routing : routing
# window : window
# sdvrptw : sdvrptw
# rute : rute
# kendaraan : kendara
# melayani : layan
# sekelompok : kelompok
# customer : customer
# titik : titik
# depot : depot
# berangkat : berangkat
# agen : agen
# permintaan : minta
# melebihi : lebih
# kapasitas : kapasitas
# angkut : angkut
# dikunjungi : kunjung
# kali : kali
# menyelesaikan : selesai
# pencarian : cari
# langsung : langsung
# tujuannya : tuju
# optimal : optimal
# pendistribusian : distribusi
# barang : barang
# jenis : jenis
# batasan : batas
# mendistribusikan : distribusi
# kurun : kurun
# kerja : kerja
# pintar : pintar
# kip : kip
# pemberian : beri
# bantuan : bantu
# tunai : tunai
# usia : usia
# berasal : asal
# keluarga : keluarga
# miskin : miskin
# rentan : rentan
# memenuhi : penuh
# ditetapkan : tetap
# dipenuhi : penuh
# menyebabkan : sebab
# penyeleksian : seleksi
# calon : calon
# penerima : terima
# berkalikali : berkalikali
# memakan : makan
# pelaksanaanya : pelaksanaanya
# berhak : hak
# memperhitungkan : hitung
# pengambilan : ambil
# gabungan : gabung
# ahptopsis : ahptopsis
# dibandingankan : dibandingankan
# promethee : promethee
# dicari : cari
# receiver : receiver
# operating : operating
# characteristic : characteristic
# roc : roc
# perhitungan : hitung
# dibanding : banding
# bandingkan : banding
# rekomendasi : rekomendasi
# terbaik : baik
# studi : studi
# undergraduate : undergraduate
# thesis : thesis
# student : student
# scientific : scientific
# activity : activity
# accountable : accountable
# also : also
# needs : needs
# supervision : supervision
# examination : examination
# lecturers : lecturers
# make : make
# sure : sure
# quality : quality
# therefore : therefore
# supervisor : supervisor
# examiner : examiner
# should : should
# person : person
# expert : expert
# specific : specific
# theme : theme
# build : build
# examiners : examiners
# recommendation : recommendation
# proposal : proposal
# seminar : seminar
# applied : applied
# contentbased : contentbased
# focuses : focuses
# content : content
# report : report
# reference : reference
# grouped : grouped
# kmeans : kmeans
# clustering : clustering
# closeness : closeness
# calculated : calculated
# every : every
# centroid : centroid
# produced : produced
# will : will
# recommend : recommend
# cluster : cluster
# performed : performed
# measuring : measuring
# ordered : ordered
# euclidean : euclidean
# error : error
# means : means
# level : level
# range : range
# scoring : scoring
# subset : subset
# actual : actual
# membaca : baca
# kegiatan : giat
# manusianamun : manusianamun
# rendahnya : rendah
# kesadaran : sadar
# indonesiaberdampak : indonesiaberdampak
# survey : survey
# mengkaji : kaji
# literasi : literasi
# bangsa : bangsa
# kedalam : dalam
# rendahsalah : rendahsalah
# cerita : cerita
# interaktif : interaktif
# minat : minat
# unity : unity
# game : game
# engine : engine
# android : android
# harapan : harap
# melewati : lewat
# tahapsebagai : tahapsebagai
# sketsa : sketsa
# alur : alur
# dilanjutkan : lanjut
# enginesebelum : enginesebelum
# dipublikasikan : publikasi
# publik : publik
# penulis : tulis
# konsep : konsep
# pengisian : isi
# kuisioner : kuisioner
# berusia : usia
# tahunbarulah : tahunbarulah
# masif : masif
# pilihan : pilih
# moral : moral
# pesan : pesan
# terkandung : kandung
# diimplementasikan : implementasi
# androidmembacacerita : androidmembacacerita
# anakunity : anakunity
# predicting : predicting
# tomato : tomato
# maturity : maturity
# major : major
# factor : factor
# affects : affects
# glucose : glucose
# becomes : becomes
# side : side
# still : still
# visibility : visibility
# directly : directly
# however : however
# disadvantage : disadvantage
# subjective : subjective
# nature : nature
# sorting : sorting
# operator : operator
# inconsistent : inconsistent
# approach : approach
# predicted : predicted
# tomatoes : tomatoes
# predict : predict
# backpropagation : backpropagation
# vector : vector
# sample : sample
# determined : determined
# red : red
# histogram : histogram
# rgb : rgb
# hsv : hsv
# determination : determination
# meanwhile : meanwhile
# prediction : prediction
# linear : linear
# regression : regression
# models : models
# hidden : hidden
# screen : screen
# neurons : neurons
# mse : mse
# equation : equation
# penggunaan : guna
# variabel : variabel
# dummy : dummy
# direkomendasikan : rekomendasi
# penyakit : sakit
# diabetes : diabetes
# mellitus : mellitus
# dm : dm
# faktorfaktor : faktorfaktor
# penyebab : sebab
# nila : nila
# nonbiner : nonbiner
# kejadian : jadi
# berhubungan : hubung
# konten : konten
# pemecahan : pecah
# biner : biner
# spesifik : spesifik
# membahas : bahas
# fitur : fitur
# cfs : cfs
# eval : eval
# seimbang : imbang
# unbalance : unbalance
# undersampling : undersampling
# spreadsubsample : spreadsubsample
# oversampling : oversampling
# replicated : replicated
# over : over
# sampling : sampling
# seleksi : seleksi
# ditarik : tarik
# variable : variable
# membuktikan : bukti
# menspesifikasikan : spesifikasi
# menstabilkan : stabil
# mempengaruhi : pengaruh
# ratarata : ratarata
# status : status
# kembalinya : kembali
# teknik : teknik
# menemukan : temu
# aturan : atur
# asosiatif : asosiatif
# kombinasi : kombinasi
# item : item
# asosiasi : asosiasi
# fp : fp
# growth : growth
# ctpro : ctpro
# penerapan : terap
# memproduksi : produksi
# semantic : semantic
# basis : basis
# pengetahuan : tahu
# knowledge : knowledge
# base : base
# ontology : ontology
# ir : ir
# interestingness : interestingness
# rules : rules
# tingkat : tingkat
# keterkaitan : kait
# serangkaian : rangkai
# eksperimental : eksperimental
# arao : arao
# pengukuran : ukur
# tambahan : tambah
# lift : lift
# ara : ara
# memudahkan : mudah
# disimpulkan : simpul
# measure : measure
# online : online
# reviews : reviews
# ditemui : temu
# pembelian : beli
# sayangnya : sayang
# produk : produk
# teks : teks
# seksama : seksama
# bintang : bintang
# benarbenar : benarbenar
# menggambarkan : gambar
# opini : opini
# amazon : amazon
# movies : movies
# tv : tv
# logistic : logistic
# perbedaan : beda
# signifikan : signifikan
# disiratkan : sirat
# user : user
# ditulisnya : tulis
# dipilihnya : pilih
# beda : beda
# pvalue : pvalue
# smote : smote
# unproportional : unproportional
# proportional : proportional
# diajukan : aju
# imbalanced : imbalanced
# peningkatan : tingkat
# kelas : kelas
# minoritas : minoritas
# makanan : makan
# pendamping : damping
# susu : susu
# mpasi : mpasi
# bayi : bayi
# nutrisi : nutrisi
# terpenuhi : penuh
# asi : asi
# bertahap : tahap
# disesuaikan : sesuai
# kondisi : kondisi
# alergi : alergi
# diderita : derita
# malnutrisi : malnutrisi
# mengintegrasikan : integrasi
# menganalisis : analis
# kelemahan : lemah
# masingmasing : masingmasing
# penunjang : tunjang
# menu : menu
# mempelajari : ajar
# perilaku : perilaku
# profil : profil
# kandungan : kandung
# gizi : gizi
# berhasil : hasil
# mengambil : ambil
# penyesuaian : sesuai
# komputasi : komputasi
# integrasi : integrasi
# mobile : mobile
# mudah : mudah
# diakses : akses
# kepuasan : puas
# scale : scale
# sus : sus
# grade : grade
# dipahami : paham
# resep : resep
# diploma : diploma
# iii : iii
# informatika : informatika
# universitas : universitas
# sebelas : sebelas
# maret : maret
# wadah : wadah
# menampung : tampung
# mahasiswanya : mahasiswa
# mengembangkan : kembang
# bakat : bakat
# diluar : luar
# jam : jam
# perkuliahan : kuliah
# dinamakan : nama
# kelompok : kelompok
# jurusan : jurus
# pemrograman : pemrograman
# multimedia : multimedia
# digital : digital
# forensic : forensic
# mengikuti : ikut
# mahasiswa : mahasiswa
# kebebasan : bebas
# kehendak : hendak
# kenyataannya : nyata
# kebingungan : bingung
# kebimbangan : bimbang
# spk : spk
# pertimbangan : timbang
# mata : mata
# kuliah : kuliah
# dosen : dosen
# prestasi : prestasi
# keterampilan : terampil
# dibangun : bangun
# framework : framework
# yii : yii
# bahasa : bahasa
# mysql : mysql
# perhitungannya : hitung
# potentially : potentially
# all : all
# pairwise : pairwise
# rankings : rankings
# possible : possible
# alternatives : alternatives
# paprika : paprika
# didapatkan : dapat
# menampilkan : tampil
# dijadikan : jadi
# menerbitkan : terbit
# artikel : artikel
# ilmiah : ilmiah
# mengklasifikasikan : klasifikasi
# dikelompokkan : kelompok
# tenaga : tenaga
# dibutuhkan : butuh
# naive : naive
# singkat : singkat
# bidang : bidang
# ilmu : ilmu
# judul : judul
# abstraknya : abstrak
# improved : improved
# kinerja : kerja
# latih : latih
# threshold : threshold
# berbeda : beda
# diujikan : uji
# kesehatan : sehat
# koperasi : koperasi
# kepercayaaan : kepercayaaan
# sehat : sehat
# pendapatan : dapat
# anggotanya : anggota
# didasarkan : dasar
# peraturan : atur
# deputi : deputi
# pengawasan : awas
# kementerian : menteri
# usaha : usaha
# menegah : tegah
# republik : republik
# no : no
# perdepiv : perdepiv
# manual : manual
# microsoft : microsoft
# excel : excel
# kesalahan : salah
# kesulitan : sulit
# hilang : hilang
# pendataan : data
# akurat : akurat
# waterfall : waterfall
# pengumpulan : kumpul
# analisa : analisa
# desain : desain
# datanya : data
# codeigniter : codeigniter
# kuisionernya : kuisionernya
# guttman : guttman
# mengelola : kelola
# neraca : neraca
# laporan : lapor
# dasar : dasar
# virtual : virtual
# reality : reality
# sektor : sektor
# pariwisata : pariwisata
# kota : kota
# wonogiri : wonogiri
# museum : museum
# kars : kars
# wisatawan : wisatawan
# mengerti : erti
# memahami : paham
# wisata : wisata
# dikembangkan : kembang
# pengembangan : kembang
# berisi : isi
# sejarah : sejarah
# diteliti : teliti
# kawasan : kawasan
# bangunan : bangun
# utamanya : utama
# ruang : ruang
# peragaan : aga
# lantai : lantai
# tinjauan : tinjau
# pustaka : pustaka
# menilai : nilai
# kelengkapan : lengkap
# deskripsi : deskripsi
# software : software
# berbentuk : bentuk
# apk : apk
# dijalankan : jalan
# sensor : sensor
# gyroscope : gyroscope
# menciptakan : cipta
# gambaran : gambar
# perkenalan : kenal
# sarana : sarana
# abdullah : abdullah
# hanif : hanif
# kios : kios
# fakultas : fakultas
# matematika : matematika
# alam : alam
# merupaya : merupaya
# papan : papan
# civitas : civitas
# akademik : akademik
# penyampaian : sampai
# ketertarikan : tari
# sasaran : sasar
# lether : lether
# distribusi : distribusi
# rancangan : rancang
# interfase : interfase
# interface : interface
# pengumuman : umum
# halaman : halaman
# gambar : gambar
# vidio : vidio
# galeri : galeri
# statistik : statistik
# coba : coba
# simpulkan : simpul
# tata : tata
# letak : letak
# layout : layout
# kejelasan : jelas
# navigasi : navigasi
# kiosk : kiosk
# kemudahan : mudah
# menghapus : hapus
# cache : cache
# proxy : proxy
# server : server
# penuh : penuh
# penghapusan : hapus
# least : least
# recently : recently
# lru : lru
# frequently : frequently
# dynamic : dynamic
# aging : aging
# lfuda : lfuda
# greedydual : greedydual
# size : size
# gdsf : gdsf
# jaringan : jaring
# lokal : lokal
# gedung : gedung
# baabapsi : baabapsi
# hit : hit
# byte : byte
# persentase : persentase
# penghematan : hemat
# unggul : unggul
# dicky : dicky
# agita : agita
# cahya : cahya
# manajemen : manajemen
# organisasi : organisasi
# simao : simao
# luput : luput
# pengarispan : pengarispan
# kelembagaan : lembaga
# terpusat : pusat
# berjalannya : jalan
# membutuhkan : butuh
# perencanaan : rencana
# pemantauan : pantau
# pengevaluasian : evaluasi
# dikemas : kemas
# koordinasi : koordinasi
# daya : daya
# pengorganisasian : organisasi
# penetapan : tetap
# pengarahan : arah
# layanan : layan
# keberjalanan : jalan
# dikhususkan : khusus
# manapun : mana
# didesain : desain
# universal : universal
# tugas : tugas
# pemonitoringan : pemonitoringan
# kepengurusan : urus
# uns : uns
# teletak : tetak
# upt : upt
# perpustakaan : pustaka
# gagasan : gagas
# pendirian : diri
# pengamanan : aman
# koleksi : koleksi
# warisan : waris
# diresmikan : resmi
# terbilang : bilang
# promosi : promosi
# media : media
# memperkuat : kuat
# penggambaran : gambar
# dimensi : dimensi
# berinteraksi : interaksi
# lingkungan : lingkung
# maya : maya
# seakan : akan
# keuntungan : untung
# dimanfaatkan : manfaat
# dibuatlah : buat
# tahapan : tahap
# unsbaru : unsbaru
# objekobjek : objekobjek
# ruangan : ruang
# bendabenda : bendabenda
# didalam : dalam
# blender : blender
# coreldraw : coreldraw
# audio : audio
# audacity : audacity
# file : file
# unityd : unityd
# snort : snort
# firewall : firewall
# dikonfigurasi : konfigurasi
# terminal : terminal
# linux : linux
# konfigurasi : konfigurasi
# input : input
# alert : alert
# mempermudah : mudah
# monitoring : monitoring
# diterminal : terminal
# email : email
# telegram : telegram
# aktifitas : aktifitas
# mode : mode
# inline : inline
# modul : modul
# daqafpacket : daqafpacket
# blok : blok
# serangan : serang
# iptables : iptables
# protokol : protokol
# smtp : smtp
# id : id
# api : api
# diharapakan : diharapakan
# diaplikasikan : aplikasi
# notifikasi : notifikasi
# pos : pos
# stateowned : stateowned
# company : company
# engaged : engaged
# freight : freight
# forwarding : forwarding
# here : here
# answer : answer
# resolve : resolve
# complaints : complaints
# mention : mention
# direct : direct
# message : message
# account : account
# manually : manually
# weaknesses : weaknesses
# submitting : submitting
# tweets : tweets
# unstructured : unstructured
# difficult : difficult
# channel : channel
# existing : existing
# areas : areas
# addressed : addressed
# immediately : immediately
# not : not
# number : number
# similar : similar
# several : several
# these : these
# problems : problems
# categories : categories
# namely : namely
# delays : delays
# errors : errors
# sending : sending
# failures : failures
# guarantee : guarantee
# goods : goods
# personnel : personnel
# speed : speed
# response : response
# support : support
# machine : machine
# svm : svm
# comparing : comparing
# polynomial : polynomial
# rbf : rbf
# kernels : kernels
# finding : finding
# best : best
# parameters : parameters
# fold : fold
# cross : cross
# validation : validation
# then : then
# fscore : fscore
# sought : sought
# confussion : confussion
# matrix : matrix
# experiment : experiment
# kernel : kernel
# followed : followed
# last : last
# while : while
# respectively : respectively
# so : so
# concluded : concluded
# classified : classified
# properly : properly
# non : non
# deteksi : deteksi
# virus : virus
# dengue : dengue
# imunistiokimia : imunistiokimia
# streptavidin : streptavidin
# biotin : biotin
# complex : complex
# apusan : apusan
# darah : darah
# tebal : tebal
# tipis : tipis
# infeksi : infeksi
# leukosit : leukosit
# rendah : rendah
# pendeteksian : deteksi
# otomatis : otomatis
# menghitung : hitung
# mengklasifikasi : klasifikasi
# terinfeksi : infeksi
# mikroskopis : mikroskopis
# mendeteksi : deteksi
# sel : sel
# gramschmidt : gramschmidt
# orthogonalization : orthogonalization
# grayscale : grayscale
# berkontras : kontras
# pelembutan : lembut
# circularity : circularity
# pembersihan : bersih
# noise : noise
# pasca : pasca
# vektor : vektor
# immunositokimia : immunositokimia
# sbpc : sbpc
# keamanan : aman
# menjaga : jaga
# mengganggu : ganggu
# merusak : rusak
# koneksi : koneksi
# terhubung : hubung
# merugikanuntuk : merugikanuntuk
# mencegah : cegah
# kerugianseperti : kerugianseperti
# kehilangan : hilang
# datasalah : datasalah
# honeypot : honeypot
# intrusion : intrusion
# detection : detection
# ids : ids
# komputer : komputer
# sengaja : sengaja
# umpan : umpan
# penyerang : serang
# attacker : attacker
# sehinggapenyerang : sehinggapenyerang
# terjebak : jebak
# kippointrusion : kippointrusion
# dipadukan : padu
# perpaduan : padu
# room : room
# palsu : palsu
# buatan : buat
# kippo : kippo
# terbaca : baca
# penyerangan : serang
# scanning : scanning
# brute : brute
# force : force
# terperangkap : perangkap
# roompalsu : roompalsu
# terlacak : lacak
# bruteforce : bruteforce
# dilakukann : dilakukann
# password : password
# karakter : karakter
# alfabet : alfabet
# numeric : numeric
# campur : campur
# numerik : numerik
# detik : detik
# campuran : campur
# percobaan : coba
# ketiga : tiga
# terlama : lama
# national : national
# unas : unas
# un : un
# government : government
# evaluation : evaluation
# determine : determine
# education : education
# depends : depends
# success : success
# students : students
# working : working
# exam : exam
# questions : questions
# material : material
# graduate : graduate
# competency : competency
# standard : standard
# standar : standar
# kompetensi : kompetensi
# lulusan : lulus
# skl : skl
# various : various
# themes : themes
# useful : useful
# knowing : knowing
# generalized : generalized
# model : model
# gvsm : gvsm
# knn : knn
# classifying : classifying
# similarity : similarity
# words : words
# appear : appear
# another : another
# classifies : classifies
# analyzing : analyzing
# subjects : subjects
# got : got
# kredit : kredit
# pinjaman : pinjam
# bank : bank
# xyz : xyz
# timbul : timbul
# pelaksanaan : laksana
# perjanjian : janji
# perbankan : perban
# debitur : debitur
# lalai : lalai
# kewajibannya : wajib
# macet : macet
# penanggulangan : tanggulang
# pembatasan : batas
# tree : tree
# cart : cart
# random : random
# forest : forest
# hyperparameter : hyperparameter
# optimization : optimization
# ditemukan : temu
# ketidakseimbangan : ketidakseimbangan
# rus : rus
# synthetic : synthetic
# minority : minority
# technique : technique
# menunjukan : tunjuk
# nestimators : nestimators
# taksasi : taksasi
# agunan : agun
# jangka : jangka
# penghasilan : hasil
# banyaknya : banyak
# dipertimbangkan : timbang
# meminimalisir : meminimalisir
# nanda : nanda
# rahma : rahma
# ananta : ananta
# faiz : faiz
# kamal : kamal
# computational : computational
# thinking : thinking
# robotika : robotika
# ditinjau : tinjau
# gaya : gaya
# kolb : kolb
# skripsi : skripsi
# keguruan : guru
# juli : juli
# peran : peran
# acuan : acu
# dilaksanakan : laksana
# kampus : kampus
# jptk : jptk
# pabelan : pabelan
# kualitatif : kualitatif
# deksriptif : deksriptif
# diikuti : ikut
# partisipan : partisipan
# ptik : ptik
# dibidang : bidang
# aktifispragmatis : aktifispragmatis
# aktifisteoris : aktifisteoris
# reflectorteoris : reflectorteoris
# reflektorpragmatis : reflektorpragmatis
# kecenderungan : cenderung
# berbedabeda : berbedabeda
# dasarnya : dasar
# kecuali : kecuali
# pengajar : ajar
# peserta : serta
# didik : didik
# dihadapinya : hadap
# perception : perception
# acceptance : acceptance
# implementation : implementation
# technology : technology
# analyze : analyze
# application : application
# school : school
# policies : policies
# tam : tam
# detail : detail
# discuss : discuss
# schoology : schoology
# have : have
# been : been
# implemented : implemented
# six : six
# months : months
# qualitative : qualitative
# descriptive : descriptive
# population : population
# teachers : teachers
# details : details
# engineering : engineering
# departement : departement
# who : who
# taking : taking
# purposive : purposive
# conditional : conditional
# samples : samples
# meet : meet
# taken : taken
# miles : miles
# huberman : huberman
# respondents : respondents
# received : received
# perceptions : perceptions
# ease : ease
# use : use
# benefits : benefits
# considered : considered
# influence : influence
# attitudes : attitudes
# behavior : behavior
# improving : improving
# they : they
# more : more
# disciplined : disciplined
# collecting : collecting
# assignments : assignments
# diligent : diligent
# conventional : conventional
# at : at
# vocational : vocational
# preparing : preparing
# first : first
# doing : doing
# introduction : introduction
# firmansyah : firmansyah
# utomo : utomo
# dipadu : padu
# group : group
# investigation : investigation
# keaktifan : aktif
# pelajaran : ajar
# smk : smk
# juni : juni
# konvensional : konvensional
# quasi : quasi
# experimental : experimental
# design : design
# pretestposttest : pretestposttest
# control : control
# populasi : populasi
# negeri : negeri
# sampel : sampel
# pretest : pretest
# posttest : posttest
# lembar : lembar
# keseimbangan : imbang
# normalitas : normalitas
# homogenitas : homogenitas
# hipotesis : hipotesis
# efektivitas : efektivitas
# ojs : ojs
# journal : journal
# opensource : opensource
# journals : journals
# many : many
# people : people
# easy : easy
# implement : implement
# features : features
# such : such
# editor : editor
# submission : submission
# comprehensive : comprehensive
# indexing : indexing
# etc : etc
# does : does
# any : any
# suggest : suggest
# suitable : suitable
# articles : articles
# users : users
# develop : develop
# embed : embed
# contents : contents
# some : some
# parts : parts
# article : article
# title : title
# scope : scope
# cosine : cosine
# matching : matching
# recommendations : recommendations
# compared : compared
# find : find
# most : most
# appropriate : appropriate
# score : score
# given : given
# than : than
# percentage : percentage
# yogi : yogi
# wahyu : wahyu
# pangestu : pangestu
# cloud : cloud
# computing : computing
# sawit : sawit
# bertransformasi : transformasi
# google : google
# suite : suite
# materi : materi
# mengakses : akses
# ujian : uji
# kolaborasi : kolaborasi
# tkj : tkj
# validitas : validitas
# reabilitas : reabilitas
# kemudahaan : kemudahaan
# dibuktikan : bukti
# paired : paired
# ttest : ttest
# signifikansi : signifikansi
# indikator : indikator
# kompabilitas : kompabilitas
# reliabilitas : reliabilitas
# fungsionalitas : fungsionalitas
# ketersediaan : sedia
# siginifikan : siginifikan
# linier : linier
# simpulan : simpul
# saranaprasarana : saranaprasarana
# pendidik : didik
# kompeten : kompeten
# memperbaiki : baik
# mutu : mutu
# daerah : daerah
# diperhatikan : perhati
# muatan : muat
# sebanding : banding
# ekspositori : ekspositori
# kebiasaan : biasa
# guru : guru
# partisipasi : partisipasi
# partisipatif : partisipatif
# berkelompok : kelompok
# berpikir : pikir
# kritis : kritis
# kooperatif : kooperatif
# think : think
# pair : pair
# square : square
# kuantitatif : kuantitatif
# clustersamplingarea : clustersamplingarea
# eksperimen : eksperimen
# tes : tes
# kefahaman : kefahaman
# tingginya : tinggi
# interaksi : interaksi
# aktif : aktif
# ditimbulkan : timbul
# dikelas : kelas
# disbanding : disbanding
# meingkatkan : meingkatkan
# mayoritas : mayoritas
# convolutional : convolutional
# neural : neural
# cnn : cnn
# pengenalan : kenal
# layer : layer
# konvolusi : konvolusi
# maxpooling : maxpooling
# bergantian : ganti
# fully : fully
# connected : connected
# arsitektur : arsitektur
# memaksakan : paksa
# sifat : sifat
# menghancurkan : hancur
# membawa : bawa
# net : net
# allcnn : allcnn
# bersaing : saing
# blood : blood
# smear : smear
# tersegmentasi : segmentasi
# batik : batik
# hasilnya : hasil
# custom : custom
# trending : trending
# topic : topic
# topik : topik
# trend : trend
# terkadang : terkadang
# sulit : sulit
# peneliti : teliti
# pengelompokan : kelompok
# olahraga : olahraga
# hiburan : hibur
# bisnis : bisnis
# berita : berita
# multilabel : multilabel
# singlelabel : singlelabel
# label : label
# multinomial : multinomial
# mnb : mnb
# knearest : knearest
# neighbors : neighbors
# beserta : serta
# tweetnya : tweetnya
# labelling : labelling
# binary : binary
# relevance : relevance
# dilatar : latar
# belakangi : belakang
# kurangnya : kurang
# subjek : subjek
# banyudono : banyudono
# deskriptif : deskriptif
# siklus : siklus
# refleksi : refleksi
# pratindakan : pratindakan
# kognitif : kognitif
# ketuntasan : tuntas
# psikomotorik : psikomotorik
# ii : ii
# discovery : discovery
# disertai : serta
# brainstorming : brainstorming
# dinas : dinas
# perdagangan : dagang
# mikro : mikro
# kabupaten : kabupaten
# madiun : madiun
# pasar : pasar
# pedagang : dagang
# bukti : bukti
# dagang : dagang
# menyulitkan : sulit
# prosesnya : proses
# mengganti : ganti
# pengerjaannya : kerja
# mencoba : coba
# pengenai : kena
# terlengkapi : lengkap
# diisi : isi
# metodologi : metodologi
# datadata : datadata
# berkaitan : kait
# merancang : rancang
# permodelan : model
# terstruktur : struktur
# konteks : konteks
# flow : flow
# dfd : dfd
# entity : entity
# relationship : relationship
# cdmconceptual : cdmconceptual
# pdm : pdm
# pysical : pysical
# phpmysql : phpmysql
# meningkat : tingkat
# penginputan : penginputan
# kerincian : kerincian
# instansi : instansi
# efisien : efisien
# pihakphak : pihakphak
# capacitated : capacitated
# cvrp : cvrp
# penentuan : tentu
# mengirimkan : kirim
# pelanggan : langgan
# particle : particle
# swarm : swarm
# pso : pso
# meminimalkan : minimal
# biaya : biaya
# perusahaan : usaha
# mineral : mineral
# pt : pt
# guwatirta : guwatirta
# sejahtera : sejahtera
# inisialisasi : inisial
# kawanan : kawan
# partikel : partikel
# posisi : posisi
# kecepatan : cepat
# bernilai : nila
# pbest : pbest
# gbest : gbest
# usulan : usul
# pengecekan : kece
# mengisi : isi
# ulang : ulang
# melanjutkan : lanjut
# perjalanannya : jalan
# terbukti : bukti
# mengurangi : kurang
# disgrafia : disgrafia
# gangguan : ganggu
# menulis : tulis
# lambat : lambat
# tulisan : tulis
# dibaca : baca
# karakteristik : karakteristik
# mengidentifikasi : identifikasi
# anakanak : anakanak
# dikategorikan : kategori
# normal : normal
# ringan : ringan
# berat : berat
# memperbaik : baik
# tidaknya : tidak
# projectbased : projectbased
# blended : blended
# grafis : grafis
# perlakuan : laku
# kuasi : kuasi
# ganda : ganda
# mengukur : ukur
# thitung : thitung
# ttabel : ttabel
# alternatif : alternatif
# ha : ha
# nol : nol
# ditolak : tolak
# dibelajarkan : ajar
# efektifitas : efektifitas
# standart : standart
# gain : gain
# kontrol : kontrol
# asti : asti
# amalina : amalina
# puspitaningrum : puspitaningrum
# infrastruktur : infrastruktur
# statis : statis
# development : development
# addie : addie
# ahli : ahli
# respon : respon
# instrumen : instrumen
# kuisionerangket : kuisionerangket
# dokumenter : dokumenter
# skor : skor
# predikat : predikat
# mey : mey
# tias : tias
# andry : andry
# pamungkas : pamungkas
# masterybased : masterybased
# kemandirian : mandiri
# kreativitas : kreativitas
# boyolali : boyolali
# penggunakan : guna
# angket : angket
# independent : independent
# mastery : mastery
# yusufa : yusufa
# mardha : mardha
# risyoni : risyoni
# smartphone : smartphone
# kecanduan : candu
# bermain : main
# indeks : indeks
# kumulatif : kumulatif
# fkip : fkip
# ipk : ipk
# expost : expost
# facto : facto
# kuisoner : kuisoner
# internet : internet
# gaming : gaming
# disorder : disorder
# igdtest : igdtest
# mengadopsi : adopsi
# kerangka : kerangka
# diagnostic : diagnostic
# statistical : statistical
# mental : mental
# disorders : disorders
# dsm : dsm
# american : american
# psychiatric : psychiatric
# depended : depended
# prodi : prodi
# xy : xy
# difilter : filter
# xz : xz
# diproses : proses
# regresi : regresi
# berganda : ganda
# parsial : parsial
# searah : arah
# sumbangan : sumbang
# intensitas : intensitas
# keterbacaan : baca
# code : code
# proyek : proyek
# ditulis : tulis
# penamaan : nama
# penulisan : tulis
# function : function
# dokumen : dokumen
# wawancara : wawancara
# triangulasi : triangulasi
# ditingkatkan : tingkat
# segi : segi
# penyederhanaan : sederhana
# komentar : komentar
# mengenalkan : kenal
# mencontohkan : contoh
# sri : sri
# puji : puji
# lestari : lestari
# edmodo : edmodo
# motivasi : motivasi
# simulasi : simulasi
# kurikulum : kurikulum
# teacher : teacher
# centered : centered
# center : center
# dinilai : nilai
# mix : mix
# independen : independen
# sig : sig
# taraf : taraf
# hitung : hitung
# tabel : tabel
# konvensianal : konvensianal
# kuesioner : kuesioner
# tergolong : golong
# pemanfaatan : manfaat
# outcomes : outcomes
# motivas : motivas
# tsaqofatun : tsaqofatun
# fani : fani
# dzahabiyah : dzahabiyah
# pbl : pbl
# tutor : tutor
# sebaya : baya
# pemahaman : paham
# menguji : uji
# analis : analis
# anava : anava
# ternormalisasi : normalisasi
# komang : komang
# talita : talita
# putri : putri
# dewati : dewati
# comparison : comparison
# jigsaw : jigsaw
# iv : iv
# reverse : reverse
# cooperative : cooperative
# terms : terms
# participation : participation
# cognitive : cognitive
# abilities : abilities
# faculty : faculty
# university : university
# june : june
# know : know
# differences : differences
# ability : ability
# basic : basic
# graphic : graphic
# toward : toward
# interaction : interaction
# type : type
# axb : axb
# factorial : factorial
# found : found
# two : two
# classes : classes
# mm : mm
# consists : consists
# questionnaire : questionnaire
# twoway : twoway
# variance : variance
# different : different
# could : could
# follows : follows
# there : there
# put : put
# consideration : consideration
# fraud : fraud
# anomaly : anomaly
# janggal : janggal
# diklasifikasi : klasifikasi
# rasionya : rasio
# bias : bias
# diatasi : atas
# neighborsundersampling : neighborsundersampling
# anomali : anomali
# transaksi : transaksi
# performa : performa
# variasi : variasi
# berturutturut : berturutturut
# true : true
# positive : positive
# false : false
# negative : negative
# nnund : nnund
# kuliner : kuliner
# tren : tren
# beredar : edar
# merta : merta
# hidangan : hidang
# dirasa : rasa
# saran : saran
# bersifat : sifat
# independence : independence
# cocok : cocok
# penyedia : sedia
# berkembang : kembang
# mangan : mangan
# kulinernya : kuliner
# merekomendasikan : rekomendasi
# kemiripan : mirip
# dihitung : hitung
# profile : profile
# dibentuk : bentuk
# restoran : restoran
# sistematika : sistematika
# listyo : listyo
# prasojo : prasojo
# interactive : interactive
# adapting : adapting
# computerbased : computerbased
# instruction : instruction
# computer : computer
# lessons : lessons
# teache : teache
# oktober : oktober
# increase : increase
# adapt : adapt
# those : those
# quantitative : quantitative
# collection : collection
# get : get
# grades : grades
# hypothesis : hypothesis
# significance : significance
# tcount : tcount
# well : well
# rejected : rejected
# accepted : accepted
# significant : significant
# where : where
# ttable : ttable
# greater : greater
# networks : networks
# muhammad : muhammad
# syarifuddinn : syarifuddinn
# rabbani : rabbani
# raspberry : raspberry
# pi : pi
# mengajar : ajar
# terbatas : batas
# spesifikasi : spesifikasi
# dihadapi : hadap
# mengatasinya : atas
# keras : keras
# berukuran : ukur
# relatif : relatif
# murah : murah
# inggris : inggris
# menambah : tambah
# tarik : tarik
# sitem : sitem
# peningkatannya : tingkat
# alat : alat
# manfaat : manfaat
# andhika : andhika
# ramadhany : ramadhany
# trainer : trainer
# wallnet : wallnet
# keahlian : ahli
# agustus : agustus
# praktik : praktik
# tolak : tolak
# ukur : ukur
# kelulusan : kelulus
# jenjang : jenjang
# menengah : tengah
# kejuruan : juru
# simulator : simulator
# jaringannya : jaring
# riil : riil
# bernama : nama
# rangkaian : rangkai
# dirancang : rancang
# topologi : topologi
# dikembangan : kembang
# munaf : munaf
# samufidi : samufidi
# inventaris : inventaris
# laboratorium : laboratorium
# terpadu : padu
# diii : diii
# keperluan : perlu
# pengelolaannya : kelola
# kebutuhansistemdesaincodingdantestingpengumpulan : kebutuhansistemdesaincodingdantestingpengumpulan
# ataustudyliteratur : ataustudyliteratur
# coding : coding
# pengelola : kelola
# mutasi : mutasi
# perbaikan : baik
# pegawai : pegawai
# ct : ct
# dikuasai : asai
# abad : abad
# berpartisipasi : partisipasi
# menyusun : susun
# permendikbud : permendikbud
# smp : smp
# sma : sma
# kanakkanak : kanakkanak
# melatih : latih
# pemikiran : pikir
# pengajaran : ajar
# kesiapan : kesiap
# barubaru : barubaru
# steam : steam
# aktivitas : aktivitas
# pencapaian : capai
# pgsd : pgsd
# tematik : tematik
# tema : tema
# handson : handson
# scaffolding : scaffolding
# komponenkomponen : komponenkomponen
# fase : fase
# eskplorasi : eskplorasi
# modularitas : modularitas
# beradaptasi : adaptasi
# abstraksi : abstraksi
# dekade : dekade
# belahan : bahan
# nomor : nomor
# smkmak : smkmak
# selaras : selaras
# stem : stem
# menstimulasi : stimulasi
# disiplin : disiplin
# belajarnya : ajar
# literatur : literatur
# adopsi : adopsi
# mengupas : kupas
# lego : lego
# mindstorm : mindstorm
# dimiliki : milik
# akibat : akibat
# melibatkan : libat
# explanatory : explanatory
# memetakan : meta
# style : style
# transkrip : transkrip
# diinterpretasikan : interpretasi
# radar : radar
# chart : chart
# sisi : sisi
# memfasilitasi : fasilitas
# abu : abu
# hamas : hamas
# video : video
# tutorial : tutorial
# september : september
# probability : probability
# denni : denni
# anggrianto : anggrianto
# kpi : kpi
# key : key
# indicator : indicator
# performances : performances
# penyusunan : susun
# rekapitulasi : rekapitulasi
# enam : enam
# describe : describe
# objectives : objectives
# artifact : artifact
# evaluate : evaluate
# communicate : communicate
# rpl : rpl
# mengacu : acu
# arti : arti
# penentu : tentu
# project : project
# pertimbanganb : pertimbanganb
# dorongan : dorong
# tercapai : capai
# kekeliruan : keliru
# perguruan : guru
# dampak : dampak
# buruk : buruk
# psikologis : psikologis
# akademis : akademis
# relasional : rasional
# kebanyakan : banyak
# arah : arah
# penggabungan : gabung
# normalisasi : normalisasi
# skenario : skenario
# kesesuaiannya : sesuai
# setuju : tuju
# devi : devi
# zetira : zetira
# fauziah : fauziah
# ditinau : tau
# xi : xi
# sakti : sakti
# gemolong : golong
# november : november
# ekperimen : ekperimen
# haji : haji
# umrah : umrah
# baitullah : baitullah
# rubaiyat : rubaiyat
# stadart : stadart
# iso : iso
# functional : functional
# suitability : suitability
# portability : portability
# black : black
# box : box
# instrument : instrument
# gt : gt
# arnold : arnold
# mlund : mlund
# dipasang : pasang
# responden : responden
# aktor : aktor
# mengoprasikan : mengoprasikan
# administrator : administrator
# diambil : ambil
# rubaityat : rubaityat
# quetionnaire : quetionnaire
# lolos : lolos
# blackbox : blackbox
# layak : layak
# shinta : shinta
# adhya : adhya
# nurpiena : nurpiena
# isyarat : isyarat
# solo : solo
# jarangnya : jarang
# pembukaan : buka
# powerpoint : powerpoint
# kertas : kertas
# berpusat : pusat
# indikatorindikator : indikatorindikator
# diuji : uji
# validasi : validasi
# bisindo : bisindo
# industri : industri
# mengevaluasi : evaluasi
# cipp : cipp
# evaluatif : evaluatif
# dewan : dewan
# pembimbing : bimbing
# koordinator : koordinator
# logis : logis
# professional : professional
# mendalam : dalam
# teori : teori
# mumpuni : mumpuni
# mendalami : dalam
# menunjangn : menunjangn
# cana : cana
# cpt : cpt
# semester : semester
# uraian : urai
# praktikum : praktikum
# levellevel : levellevel
# menantang : tantang
# mempelajarinya : ajar
# homi : homi
# bayu : bayu
# lintang : lintang
# aji : aji
# xii : xii
# memakai : pakai
# ceramah : ceramah
# bergantung : gantung
# mandiri : mandiri
# dikembangakan : dikembangakan
# usefulness : usefulness
# satisfaction : satisfaction
# komunikasi : komunikasi
# modeling : modeling
# konstruksi : konstruksi
# ketepatan : tepat
# kesesuaian : sesuai
# kebermanfaatan : manfaat
# usefulnesskebermanfaatan : usefulnesskebermanfaatan
# usekemudahan : usekemudahan
# learningkemudahan : learningkemudahan
# penilitian : penilitian
# terciptanya : cipta
# abstrack : abstrack
# apalah : apa
# menunggu : tunggu
# anuu : anuu
# novita : novita
# rahmawati : rahmawati
# technological : technological
# pedagogical : pedagogical
# tpack : tpack
# persepsi : persepsi
# januari : januari
# goal : goal
# oriented : oriented
# ketercapaian : capai
# aspekaspek : aspekaspek
# likert : likert
# rumus : rumus
# saifuddin : saifuddin
# produktif : produktif
# disekolah : seko
# tendensi : tendensi
# kearah : arah
# mengampu : ampu
# memadai : pada
# diajarkan : ajar
# pk : pk
# rezza : rezza
# fariszal : fariszal
# hisyam : hisyam
# chaizara : chaizara
# contextaware : contextaware
# smart : smart
# green : green
# building : building
# home : home
# desember : desember
# kenyamanan : nyaman
# penghuninya : hun
# teknolgi : teknolgi
# cerdas : cerdas
# purwarupa : purwarupa
# rincian : rincian
# ditentukan : tentu
# pandangan : pandang
# peniliaian : peniliaian
# buildingakan : buildingakan
# masukan : masuk
# optimalisasi : optimalisasi
# penyempurnaan : sempurna
# improve : improve
# activeness : activeness
# administration : administration
# mind : mind
# mapping : mapping
# sukoharjo : sukoharjo
# classroom : classroom
# action : action
# ptk : ptk
# conducted : conducted
# cycles : cycles
# four : four
# stages : stages
# planning : planning
# implementing : implementing
# observing : observing
# reflecting : reflecting
# seen : seen
# indicators : indicators
# achieved : achieved
# completeness : completeness
# aspect : aspect
# preaction : preaction
# cycle : cycle
# second : second
# perkembangan : kembang
# era : era
# digitalisasi : digitalisasi
# pesat : pesat
# berdampak : dampak
# generasi : generasi
# milenial : milenial
# mendeskripsikan : deskripsi
# styles : styles
# ils : ils
# felder : felder
# silverman : silverman
# strategi : strategi
# pembelajar : ajar
# active : active
# reflective : reflective
# sensing : sensing
# intuitive : intuitive
# pemasukan : pasu
# informasitipe : informasitipe
# verbal : verbal
# pemrosesan : pemrosesan
# sequential : sequential
# global : global
# {'bagus': 'bagus', 'prasetyo': 'prasetyo', 'hutomo': 'hutomo', 'pembuatan': 'buat', 'sistem': 'sistem', 'administrasi': 'administrasi', 'rawat': 'rawat', 'jalan': 'jalan', 'berbasis': 'bas', 'php': 'php', 'rumah': 'rumah', 'sakit': 'sakit', 'kepentingan': 'penting', 'pengolahan': 'olah', 'data': 'data', 'pendaftaran': 'daftar', 'pasien': 'pasien', 'tindakan': 'tindak', 'pembayaran': 'bayar', 'menangani': 'tangan', 'berjalan': 'jalan', 'cepat': 'cepat', 'kelola': 'kelola', 'valid': 'valid', 'pku': 'pku', 'muhammadiyah': 'muhammadiyah', 'surakarta': 'surakarta', 'memiliki': 'milik', 'kompleks': 'kompleks', 'pengelolaan': 'kelola', 'efektif': 'efektif', 'fungsi': 'fungsi', 'kartu': 'kartu', 'berguna': 'guna', 'pengenal': 'kenal', 'observasi': 'observasi', 'memperoleh': 'oleh', 'proses': 'proses', 'nyata': 'nyata', 'membentuk': 'bentuk', 'informasi': 'informasi', 'atribut': 'atribut', 'penyimpanan': 'simpan', 'database': 'database', 'dikumpulkan': 'kumpul', 'olah': 'olah', 'komponen': 'komponen', 'perancangan': 'ancang', 'dimana': 'mana', 'erd': 'erd', 'usecase': 'usecase', 'class': 'class', 'diagram': 'diagram', 'sequence': 'sequence', 'tampilan': 'tampil', 'hasil': 'hasil', 'diperoleh': 'oleh', 'penelitian': 'teliti', 'diolah': 'olah', 'ditangani': 'tangan', 'pengujian': 'uji', 'memeriksa': 'periksa', 'program': 'program', 'lancar': 'lancar', 'percetakan': 'cetak', 'anggota': 'anggota', 'admin': 'admin', 'penambahan': 'tambah', 'poliklinik': 'poliklinik', 'diagnosis': 'diagnosis', 'cetak': 'cetak', 'nota': 'nota', 'kunci': 'kunci', 'web': 'web', 'today': 'today', 'customers': 'customers', 'can': 'can', 'easily': 'easily', 'submit': 'submit', 'their': 'their', 'review': 'review', 'or': 'or', 'opinion': 'opinion', 'of': 'of', 'product': 'product', 'service': 'service', 'from': 'from', 'natasha': 'natasha', 'skin': 'skin', 'care': 'care', 'through': 'through', 'mentions': 'mentions', 'tweet': 'tweet', 'be': 'be', 'identified': 'identified', 'emotions': 'emotions', 'costumers': 'costumers', 'after': 'after', 'using': 'using', 'products': 'products', 'services': 'services', 'this': 'this', 'research': 'research', 'proposes': 'proposes', 'to': 'to', 'classify': 'classify', 'according': 'according', 'ekman': 'ekman', 'that': 'that', 'is': 'is', 'joy': 'joy', 'surprise': 'surprise', 'anger': 'anger', 'fear': 'fear', 'sad': 'sad', 'and': 'and', 'disgust': 'disgust', 'by': 'by', 'nave': 'nave', 'bayes': 'bayes', 'classifier': 'classifier', 'chosen': 'chosen', 'because': 'because', 'its': 'its', 'advantages': 'advantages', 'simple': 'simple', 'fast': 'fast', 'high': 'high', 'accuracy': 'accuracy', 'the': 'the', 'dataset': 'dataset', 'in': 'in', 'study': 'study', 'amounted': 'amounted', 'with': 'with', 'division': 'division', 'for': 'for', 'each': 'each', 'noemotions': 'noemotions', 'results': 'results', 'show': 'show', 'method': 'method', 'has': 'has', 'good': 'good', 'performance': 'performance', 'twitter': 'twitter', 'average': 'average', 'rate': 'rate', 'on': 'on', 'emotional': 'emotional', 'classification': 'classification', 'without': 'without', 'involving': 'involving', 'shows': 'shows', 'highest': 'highest', 'recall': 'recall', 'value': 'value', 'precision': 'precision', 'was': 'was', 'fmeasure': 'fmeasure', 'mean': 'mean', 'although': 'although', 'higher': 'higher', 'very': 'very', 'low': 'low', 'which': 'which', 'ros': 'ros', 'resampling': 'resampling', 'algorithm': 'algorithm', 'values': 'values', 'are': 'are', 'keyword': 'keyword', 'purpose': 'purpose', 'present': 'present', 'symmetrical': 'symmetrical', 'singular': 'singular', 'decomposition': 'decomposition', 'representation': 'representation', 'ssvdr': 'ssvdr', 'gabor': 'gabor', 'filter': 'filter', 'under': 'under', 'illumination': 'illumination', 'effect': 'effect', 'face': 'face', 'recognition': 'recognition', 'proposed': 'proposed', 'normalize': 'normalize', 'illuminated': 'illuminated', 'images': 'images', 'caused': 'caused', 'difference': 'difference', 'light': 'light',  ...
# ------------------------
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=83.0), HTML(value='')))
# 0     [bagus, prasetyo, hutomo, buat, sistem, admini...
# 1     [today, customers, can, easily, submit, their,...
# 2     [the, purpose, of, this, research, is, to, pre...
# 3     [abstrak, tahun, smpit, nur, hidayah, terima, ...
# 4     [didik, ajar, basis, teknologi, informasi, ter...
#                             ...
# 78    [novita, rahmawati, evaluasi, terap, technolog...
# 79    [abstrak, rezza, fariszal, hisyam, chaizara, e...
# 80    [this, study, aims, to, improve, the, activene...
# 81    [kembang, era, digitalisasi, pesat, dampak, ka...
# 82    [kembang, era, digitalisasi, pesat, dampak, ka...
# Name: abstrack_tokens_stemmed, Length: 83, dtype: object

# %%
abstrack.to_csv("Text_Preprocessing.csv")
abstrack.to_excel("Text_Preprocessing.xlsx")
